# %% [markdown]
# <a href="https://colab.research.google.com/github/GabzDeveloper451/Desafio_Python_30_Dias/blob/main/C%C3%B3pia_de_dia_13_Marcus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x= 3
print(f"a variável x={x} aqui é global")
while True:
  x=4
  if x+1 == 5:
    print(f"a variável x={x} aqui é local")
  break
# Out:
# a variável x=3 aqui é global
# a variável x=4 aqui é local

# %% [markdown]
# <a href="https://colab.research.google.com/github/GabzDeveloper451/Desafio_Python_30_Dias/blob/main/dia_9_Marcus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Use um laço for para iterar sobre a lista de frutas e imprimir cada item com sua posição.

#lista de frutas
lista_de_trufas=["jaranla","acabate", "bermogata", "nabana", "vua" ]


#imprimindo frutas com ordem

for i in range(len(lista_de_trufas)):
  print(i, lista_de_trufas[i])
# Out:
# 0 jaranla
# 1 acabate
# 2 bermogata
# 3 nabana
# 4 vua

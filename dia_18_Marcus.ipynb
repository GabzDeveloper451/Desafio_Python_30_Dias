# %% [markdown]
# <a href="https://colab.research.google.com/github/GabzDeveloper451/Desafio_Python_30_Dias/blob/main/dia_18_Marcus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Crie um dicionário para armazenar informações de uma pessoa (nome, idade, cidade).

#criando dicionário
dic_dados={"nome":"Marcus", "idade":"36", "cidade":"Itaquaquecetuba"}

#exibindo dicionário
print(dic_dados)

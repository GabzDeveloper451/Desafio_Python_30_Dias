# %% [markdown]
# <a href="https://colab.research.google.com/github/GabzDeveloper451/Desafio_Python_30_Dias/blob/main/dia%204%20Marcus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#definindo variáveis e bloqueando erros
while True:
  num_dig1=input("1º- digite um número inteiro ")
  try:
    numero1=int(num_dig1)
    if numero1 <= 0:
        print("digite um número acima de zero")
        continue
    else:
          break
  except  ValueError:
    print("digite um número inteiro")


while True:
  num_dig2=input("2º- digite um número inteiro ")
  try:
    numero2=int(num_dig2)
    if numero2 <= 0:
        print("digite um número acima de zero")
    else:
        break
  except ValueError:
    print("digite um número inteiro")


#definindo cálculos

soma=numero1+numero2
subtracao=numero1-numero2
mutiplicacao=numero1*numero2
divisao=numero1/numero2

#programando resposta

print(f"""olha, fiz algo bem simples e travei pra que não saisse do que eu precisava \n\no seu código tá lindo Biel!\n\neu fiz o mais simples possível, então lá vai ele: \n\nsoma= {soma} \n\nsubtração= {subtracao} \n\nmutiplicação= {mutiplicacao} \n\ndivisao= {divisao} \n\nBora pro dia 5!!!!""")
# Out:
# 1º- digite um número inteiro a
# digite um número inteiro
# 1º- digite um número inteiro sdsad
# digite um número inteiro
# 1º- digite um número inteiro 0
# digite um número acima de zero
# 1º- digite um número inteiro 0
# digite um número acima de zero
# 1º- digite um número inteiro asdas
# digite um número inteiro
# 1º- digite um número inteiro 0
# digite um número acima de zero
# 1º- digite um número inteiro 1
# 2º- digite umnúmero inteiro asdas
# digite um número inteiro
# 2º- digite umnúmero inteiro 0
# digite um número acima de zero
# 2º- digite umnúmero inteiro cxzcxz
# digite um número inteiro
# 2º- digite umnúmero inteiro dwdwq
# digite um número inteiro
# 2º- digite umnúmero inteiro 0
# digite um número acima de zero
# 2º- digite umnúmero inteiro 2
# olha, fiz algo bem simples e travei pra que não saisse do que eu precisava
#
# o seu código tá lindo Biel!
#
# eu fiz o mais simples possível, então lá vai ele:
#
# soma= 3
#
# subtração= -1
#
# mutiplicação= 2
#
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/GabzDeveloper451/Desafio_Python_30_Dias/blob/main/dia_23_Marcus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Leitura de Arquivos Crie um arquivo de texto simples (meu_arquivo.txt) e
#escreva um programa para ler e imprimir seu conteúdo.

#definindo arquivo e texto
arquivo = 'meu_arquivo.txt'
texto=input("digite uma frase para gerar o arquivo " )

#gerando o arquivo
try:
    with open(arquivo, 'w') as file:
        file.write(texto)
    print(f"Arquivo '{arquivo}' criado e conteúdo escrito com sucesso.")
except:
    print(f"Ocorreu um erro ao criar ou escrever no arquivo: {e}")



# Modifique o programa do dia anterior para adicionar uma nova linha de texto ao final do arquivo.

#inserindo uma nova linha

nova_linha =input("digite uma nova linha de texto: ")

try:
    with open(arquivo, 'a') as file:
        file.write("\n" + nova_linha)
    print(f"Nova linha adicionada ao arquivo '{arquivo}'.")
except:
    print(f"Ocorreu um erro ao criar a nova linha")


    #leitura e print do arquivo
arquivo = 'meu_arquivo.txt'

try:
    with open(arquivo, 'r') as file:
        content = file.read()
        print(f"\nConteúdo do arquivo '{arquivo}':\n")
        print(content)
except:
    print(f"Ocorreu um erro ao ler o arquivo '{arquivo}'.")

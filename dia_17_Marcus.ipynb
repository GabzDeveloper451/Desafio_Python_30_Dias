# %% [markdown]
# <a href="https://colab.research.google.com/github/GabzDeveloper451/Desafio_Python_30_Dias/blob/main/dia_17_Marcus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Crie uma tupla com as coordenadas (latitude, longitude) e demonstre que ela é imutável.

#definindo coordenadas
coordenadas= (30, -30)

print(f"printando as coordenadas originais: {coordenadas}")
#mudando tupla

print("tentando printar coordenadas originais e criando mensagem de erro:")
try:
  coordenadas[0]=40
  print(coordenadas)
except TypeError:
  print("Não é possível alterar uma tupla")

# %% [markdown]
# <a href="https://colab.research.google.com/github/GabzDeveloper451/Desafio_Python_30_Dias/blob/main/dia_11_Marcus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
NUM_1 = 0
NUM_2 = 0

#"Escreva uma função que receba dois números como argumentos e retorne o maior deles."

while True:
  try:
   NUM_1=int(input("Digite o primeiro numero: "))
   NUM_2=int(input("Digite o segundo numero: "))

   if NUM_1 > NUM_2:
     print(f"O maior numero é {NUM_1}")
   else:
     print(f"O maior numero é {NUM_2}")
  except ValueError:
    print("Digite um numero valido")
    continue
  break
